# %%
#1.	Store a message in a variable and print it in:
#o	Uppercase
#o	Lowercase
#o	Title case (first letter capitalized)

# %%
msg="Welcome 2026, Hope 2026 will be filled with joy, prosperity and peace"
print(msg.upper())
print(msg.lower())
print(msg.title())
# Out:
# WELCOME 2026, HOPE 2026 WILL BE FILLED WITH JOY, PROSPERITY AND PEACE
# welcome 2026, hope 2026 will be filled with joy, prosperity and peace
# Welcome 2026, Hope 2026 Will Be Filled With Joy, Prosperity And Peace

# %%
#2.	Store a person’s name in a variable. Print a message such as:
#"Hello Alice, welcome to Python programming!"

# %%
name="Sita"
print(f'"Hello {name}, welcome to Python programming!"')
# Out:
# "Hello Sita, welcome to Python programming!"

# %%
#3.	Store a word in a variable and print:
#o	The first character
#o	The last character
#o	The length of the word

# %%
word="consistency"
print(word[0])
print(word[-1])
print(len(word))
# Out:
# c
# y
# 11

# %%
#4.	Find your favorite quote and print it with quotation marks. Example:
#"Mahatma Gandhi once said, “Be the change that you wish to see in the world.”

# %%
print('"Mirabai once said, "In this world of illusion, only the love of Krishna is real."')
# Out:
# "Mirabai once said, "In this world of illusion, only the love of Krishna is real."

# %%
#5.	Store two strings in different variables and print them joined with a space in between.

# %%
str1="Sita"
str2="Ram"
print(str1+" "+str2)
# Out:
# Sita Ram

# %%
#6.	Store a sentence in a variable and check if it contains the word "Python". Print True or False.

# %%
str="Python is an interpreted language."
if "Python" in str:
    print("True")
else:
    print("False")
# or
"True" if "Python" in str else "False"
# Out:
# True
# 'True'

# %%
#7.	Ask the user to enter their name and print:
#"Hello <name>, how are you today?"

# %%
name=input("Enter your name------")
print(f'Hello {name}, how are you today?')
# Out:
# Enter your name------ Supraja
# Hello Supraja, how are you today?

# %%
#8.	Ask the user to enter their age and print:
#"You are <age> years old."

# %%
age=int(input("Age:  "))
print(f'You are {age} years old')
# Out:
# Age:   27
# You are 27 years old

# %%
#9.	Ask the user for two numbers and print their:
#o	Sum
#o	Difference
#o	Product
#o	Quotient

# %%
num1=int(input("enter first number: "))
num2=int(input("enter second number: "))
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
# enter first number:  18
# enter second number:  5
# 23
# 13
# 90
# 3.6

# %%
#10.Ask the user to enter a sentence and print it reversed.

# %%
str=input("enter sentence: ")
print(str[::-1])
# Out:
# enter sentence:  How are you?
# ?uoy era woH

# %%
#11.Ask the user for their favorite color and print:
#"Wow! <color> is a beautiful color!"

# %%
fav_color=input("ENter Your Favourite color:  ")
print(f'Wow! {fav_color} is a beautiful color!')
# Out:
# ENter Your Favourite color:   Blue
# Wow! Blue is a beautiful color!

# %%
#12.Ask the user to enter a number and print True if it is greater than 50, otherwise print False

# %%
num=int(input("Enter a number: "))
"True" if num>50 else "False"
# Out:
# Enter a number:  33
# 'False'

# %%
#13.Ask the user to enter a number and print True if it is even, otherwise print False.

# %%
num=int(input("Enter a number: "))
"True" if num%2==0 else "False"
# Out:
# Enter a number:  44
# 'True'

# %%
#14.Ask the user to enter their age and check if they are eligible to vote (age ≥ 18). Print True or False.

# %%
age=int(input("Enter your age: "))
"True" if age>=18 else "False"
# Out:
# Enter your age:  27
# 'True'

# %%
#15.Ask the user to enter two numbers and print True if the first number is greater than the second, else print False.

# %%
num1=int(input("enter first number: "))
num2=int(input("enter second number: "))
"True" if num1>num2 else "False"
# Out:
# enter first number:  24
# enter second number:  45
# 'False'

# %%
#16.Ask the user to enter a word and check if its length is more than 5 characters. Print True or False.

# %%
word=input("enter a word: ")
"True" if len(word)>5 else "False"
# Out:
# enter a word:  Welcome
# 'True'

# %%
#17.Write a program that asks the user to enter a password.
#Your program should check and print:
# - True if the password length is at least 8 characters and contains the word "@" or "#".
# - False otherwise.

# %%
pwd=input("Enter a password: ")
"True" if (len(pwd)>=8 and ("&" in pwd or "#" in pwd) ) else "False"
# Out:
# Enter a password:  password
# 'False'
