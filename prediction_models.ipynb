# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
import os

path = r"C:\Users\91938\Desktop\Top Mentor\Machine Learning\1st November\Files\Project  -  Simple Linear Regression\2. Simple Linear Regression\delivery_time.csv"
print(os.path.exists(path))
# Out:
# True

# %%
data = pd.read_csv(r"C:\Users\91938\Desktop\Top Mentor\Machine Learning\1st November\Files\Project  -  Simple Linear Regression\2. Simple Linear Regression\delivery_time.csv")
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
delivery_time=data["Delivery Time"]
delivery_time
# Out:
# 0     21.00
# 1     13.50
# 2     19.75
# 3     24.00
# 4     29.00
# 5     15.35
# 6     19.00
# 7      9.50
# 8     17.90
# 9     18.75
# 10    19.83
# 11    10.75
# 12    16.68
# 13    11.50
# 14    12.03
# 15    14.88
# 16    13.75
# 17    18.11
# 18     8.00
# 19    17.83
# 20    21.50
# Name: Delivery Time, dtype: float64

# %%
sorting_time=data[["Sorting Time"]]
sorting_time
# Out:
#     Sorting Time
# 0             10
# 1              4
# 2              6
# 3              9
# 4             10
# 5              6
# 6              7
# 7              3
# 8             10
# 9              9
# 10             8
# 11             4
# 12             7
# 13             3
# 14             3
# 15             4
# 16             6
# 17             7
# 18             2
# 19             7
# 20             5

# %%
model=LinearRegression()
model.fit(sorting_time,delivery_time)
model
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(6.58273397199706)

# %%
model.coef_
# Out:
# array([1.6490199])

# %%
sorting_time_given=8
delivery_time_prediction=model.coef_*sorting_time_given+model.intercept_
delivery_time_prediction
# Out:
# array([19.77489315])

# %%
model.coef_*6+model.intercept_
# Out:
# array([16.47685335])

# %%
model.coef_*14+model.intercept_
# Out:
# array([29.66901253])

# %%
plt.figure(figsize=(4,3))
plt.scatter(sorting_time,delivery_time,color="red",label="actual")

# %%
salary_data=pd.read_csv(r"C:\Users\91938\Desktop\Top Mentor\Machine Learning\1st November\Files\Project  -  Simple Linear Regression\2. Simple Linear Regression\Salary_Data.csv")
salary_data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
exp=salary_data[["YearsExperience"]]
exp
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
salary=salary_data["Salary"]
salary
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
salary_model=LinearRegression()
salary_model.fit(exp,salary)
# Out:
# LinearRegression()

# %%
salary_model.coef_
# Out:
# array([9449.96232146])

# %%
salary_model.intercept_
# Out:
# np.float64(25792.200198668717)

# %%
predcited_salary1=salary_model.coef_*12+salary_model.intercept_
predcited_salary1
# Out:
# array([139191.74805613])

# %%
predcited_salary2=salary_model.coef_*4+salary_model.intercept_
predcited_salary2
# Out:
# array([63592.04948449])

# %%
predcited_salary3=salary_model.coef_*2.5+salary_model.intercept_
predcited_salary3
# Out:
# array([49417.10600231])

# %%
plt.figure(figsize=(4,3))
plt.scatter(exp,salary,color="red",label="actual")

# %%
#salary model is best one as itc accuracy is high when compared to delivery_time model
